# %%
print('hello')
# Out:
# hello

# %%
from dinov3_hf_gallery_classify import DinoV3HFEmbedder, find_image_files, compare_query_with_gallery
# Out:
# /home/ubuntu/anaconda/lib/python3.12/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
# Инициализация большой DINOv3 (HF) на одной GPU с FP16
embedder = DinoV3HFEmbedder(model_id="facebook/dinov3-vit7b16-pretrain-lvd1689m")
# Out:
# preprocessor_config.json:   0%|          | 0.00/585 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/48.7k [00:00<?, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/2.01G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 2
# ...

# %%
# Инициализация большой DINOv3 (HF) на одной GPU с FP16
embedder = DinoV3HFEmbedder(model_id="facebook/dinov3-vit7b16-pretrain-lvd1689m")

# Эталоны: укажите папку с 11 кропами
gallery_dir = "/home/ubuntu/diabert/dataset/crops_of_every_tool"
gallery_paths = find_image_files(gallery_dir, recursive=True, limit=11)

# Запрос: путь к одному основному изображению
query_path = "/home/ubuntu/path/to/your/query_image.jpg"  # замените

# Сравнение и вывод скорів
result = compare_query_with_gallery(embedder, gallery_paths, query_path, print_scores=True)

# Доступ к данным программно
result
